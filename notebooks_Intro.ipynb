# %%
# !git init
# !git config --global user.name "Your Name"
# !git config --global user.email "your-email@example.com"
# !git add .
# !git commit -m "Add fashion sales analysis notebook"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 get_ipython().system('git init')
#       2 get_ipython().system('git config --global user.name "Your Name"')
#       3 get_ipython().system('git config --global user.email "your-email@example.com"')
#
# OSError: Not available
